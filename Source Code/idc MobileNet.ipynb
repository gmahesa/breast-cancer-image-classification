# %% [markdown]
# jupyter notebook --NotebookApp.allow_origin='https://colab.research.google.com' --port=8888 --NotebookApp.port_retries=0

# %%
from numpy.random import seed
seed(101)

import pandas as pd
import numpy as np


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D
from tensorflow.keras.layers import Dense, Dropout, Flatten, Activation
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

import os
# import cv2
from os import walk

from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import itertools
import shutil
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
IMAGE_SIZE = 50
IMAGE_CHANNELS = 3

SAMPLE_SIZE = 25420 # the number of images we use from each of the two classes

# %%
# End of Data Preparation
### ================================================================================== ###
# Start of Model Building

# %%
train_path = 'base_dir/train_dir'
valid_path = 'base_dir/val_dir'


# num_train_samples = len(df_train)
# num_val_samples = len(df_val)
train_batch_size = 64
val_batch_size = 64


train_steps = 128
val_steps = 128

# %%
datagen = ImageDataGenerator(rescale=1.0/255,
                             shear_range = 0.2,
                             zoom_range=0.2,
                             horizontal_flip=True,
                             vertical_flip=True,
                             rotation_range=20,
                             width_shift_range=0.2,
                             height_shift_range=0.2)

train_gen = datagen.flow_from_directory(train_path,
                                        target_size=(IMAGE_SIZE,IMAGE_SIZE),
                                        batch_size=train_batch_size,
                                        class_mode='categorical')

val_gen = datagen.flow_from_directory(valid_path,
                                        target_size=(IMAGE_SIZE,IMAGE_SIZE),
                                        batch_size=val_batch_size,
                                        class_mode='categorical')

# Note: shuffle=False causes the test dataset to not be shuffled
test_gen = datagen.flow_from_directory(valid_path,
                                        target_size=(IMAGE_SIZE,IMAGE_SIZE),
                                        batch_size=1,
                                        class_mode='categorical',
                                        shuffle=False)
# Out:
# Found 40672 images belonging to 2 classes.
# Found 10168 images belonging to 2 classes.
# Found 10168 images belonging to 2 classes.

# %%
MobileNet_model = keras.applications.mobilenet.MobileNet(input_shape =(50,50,3) ,weights='imagenet', include_top=False)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
MobileNet_model.trainable = False

# %%
MobileNet_model.summary()
# Out:
# Model: "mobilenet_1.00_224"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 50, 50, 3)]       0
#
#  conv1 (Conv2D)              (None, 25, 25, 32)        864
#
#  conv1_bn (BatchNormalizatio  (None, 25, 25, 32)       128
#  n)
#
#  conv1_relu (ReLU)           (None, 25, 25, 32)        0
#
#  conv_dw_1 (DepthwiseConv2D)  (None, 25, 25, 32)       288
#
#  conv_dw_1_bn (BatchNormaliz  (None, 25, 25, 32)       128
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, 25, 25, 32)        0
#
#  conv_pw_1 (Conv2D)          (None, 25, 25, 64)        2048
#
#  conv_pw_1_bn (BatchNormaliz  (None, 25, 25, 64)       256
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, 25, 25, 64)        0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 26, 26, 64)        0
#
#  conv_dw_2 (DepthwiseConv2D)  (None, 12, 12, 64)       576
#
#  conv_dw_2_bn (BatchNormaliz  (None, 12, 12, 64)       256
#  ation)
#
#  conv_dw_2_relu (ReLU)       (None, 12, 12, 64)        0
#
#  conv_pw_2 (Conv2D)          (None, 12, 12, 128)       8192
#
#  conv_pw_2_bn (BatchNormaliz  (None, 12, 12, 128)      512
#  ation)
#
#  conv_pw_2_relu (ReLU)       (None, 12, 12, 128)       0
#
#  conv_dw_3 (DepthwiseConv2D)  (None, 12, 12, 128)      1152
#
#  conv_dw_3_bn (BatchNormaliz  (None, 12, 12, 128)      512
#  ation)
#
#  conv_dw_3_relu (ReLU)       (None, 12, 12, 128)       0
#
#  conv_pw_3 (Conv2D)          (None, 12, 12, 128)       16384
#
#  conv_pw_3_bn (BatchNormaliz  (None, 12, 12, 128)      512
#  ation)
#
#  conv_pw_3_relu (ReLU)       (None, 12, 12, 128)       0
#
#  conv_pad_4 (ZeroPadding2D)  (None, 13, 13, 128)       0
#
#  conv_dw_4 (DepthwiseConv2D)  (None, 6, 6, 128)        1152
#
#  conv_dw_4_bn (BatchNormaliz  (None, 6, 6, 128)        512
#  ation)
#
#  conv_dw_4_relu (ReLU)       (None, 6, 6, 128)         0
#
#  conv_pw_4 (Conv2D)          (None, 6, 6, 256)         32768
#
#  conv_pw_4_bn (BatchNormaliz  (None, 6, 6, 256)        1024
#  ation)
#
#  conv_pw_4_relu (ReLU)       (None, 6, 6, 256)         0
#
#  conv_dw_5 (DepthwiseConv2D)  (None, 6, 6, 256)        2304
#
#  conv_dw_5_bn (BatchNormaliz  (None, 6, 6, 256)        1024
#  ation)
#
#  conv_dw_5_relu (ReLU)       (None, 6, 6, 256)         0
#
#  conv_pw_5 (Conv2D)          (None, 6, 6, 256)         65536
#
#  conv_pw_5_bn (BatchNormaliz  (None, 6, 6, 256)        1024
#  ation)
#
#  conv_pw_5_relu (ReLU)       (None, 6, 6, 256)         0
#
#  conv_pad_6 (ZeroPadding2D)  (None, 7, 7, 256)         0
#
#  conv_dw_6 (DepthwiseConv2D)  (None, 3, 3, 256)        2304
#
#  conv_dw_6_bn (BatchNormaliz  (None, 3, 3, 256)        1024
#  ation)
#
#  conv_dw_6_relu (ReLU)       (None, 3, 3, 256)         0
#
#  conv_pw_6 (Conv2D)          (None, 3, 3, 512)         131072
#
#  conv_pw_6_bn (BatchNormaliz  (None, 3, 3, 512)        2048
#  ation)
#
#  conv_pw_6_relu (ReLU)       (None, 3, 3, 512)         0
#
#  conv_dw_7 (DepthwiseConv2D)  (None, 3, 3, 512)        4608
#
#  conv_dw_7_bn (BatchNormaliz  (None, 3, 3, 512)        2048
#  ation)
#
#  conv_dw_7_relu (ReLU)       (None, 3, 3, 512)         0
#
#  conv_pw_7 (Conv2D)          (None, 3, 3, 512)         262144
#
#  conv_pw_7_bn (BatchNormaliz  (None, 3, 3, 512)        2048
#  ation)
#
#  conv_pw_7_relu (ReLU)       (None, 3, 3, 512)         0
#
#  conv_dw_8 (DepthwiseConv2D)  (None, 3, 3, 512)        4608
#
#  conv_dw_8_bn (BatchNormaliz  (None, 3, 3, 512)        2048
#  ation)
#
#  conv_dw_8_relu (ReLU)       (None, 3, 3, 512)         0
#
#  conv_pw_8 (Conv2D)          (None, 3, 3, 512)         262144
#
#  conv_pw_8_bn (BatchNormaliz  (None, 3, 3, 512)        2048
#  ation)
#
#  conv_pw_8_relu (ReLU)       (None, 3, 3, 512)         0
#
#  conv_dw_9 (DepthwiseConv2D)  (None, 3, 3, 512)        4608
#
#  conv_dw_9_bn (BatchNormaliz  (None, 3, 3, 512)        2048
#  ation)
#
#  conv_dw_9_relu (ReLU)       (None, 3, 3, 512)         0
#
#  conv_pw_9 (Conv2D)          (None, 3, 3, 512)         262144
#
#  conv_pw_9_bn (BatchNormaliz  (None, 3, 3, 512)        2048
#  ation)
#
#  conv_pw_9_relu (ReLU)       (None, 3, 3, 512)         0
#
#  conv_dw_10 (DepthwiseConv2D  (None, 3, 3, 512)        4608
#  )
#
#  conv_dw_10_bn (BatchNormali  (None, 3, 3, 512)        2048
#  zation)
#
#  conv_dw_10_relu (ReLU)      (None, 3, 3, 512)         0
#
#  conv_pw_10 (Conv2D)         (None, 3, 3, 512)         262144
#
#  conv_pw_10_bn (BatchNormali  (None, 3, 3, 512)        2048
#  zation)
#
#  conv_pw_10_relu (ReLU)      (None, 3, 3, 512)         0
#
#  conv_dw_11 (DepthwiseConv2D  (None, 3, 3, 512)        4608
#  )
#
#  conv_dw_11_bn (BatchNormali  (None, 3, 3, 512)        2048
#  zation)
#
#  conv_dw_11_relu (ReLU)      (None, 3, 3, 512)         0
#
#  conv_pw_11 (Conv2D)         (None, 3, 3, 512)         262144
#
#  conv_pw_11_bn (BatchNormali  (None, 3, 3, 512)        2048
#  zation)
#
#  conv_pw_11_relu (ReLU)      (None, 3, 3, 512)         0
#
#  conv_pad_12 (ZeroPadding2D)  (None, 4, 4, 512)        0
#
#  conv_dw_12 (DepthwiseConv2D  (None, 1, 1, 512)        4608
#  )
#
#  conv_dw_12_bn (BatchNormali  (None, 1, 1, 512)        2048
#  zation)
#
#  conv_dw_12_relu (ReLU)      (None, 1, 1, 512)         0
#
#  conv_pw_12 (Conv2D)         (None, 1, 1, 1024)        524288
#
#  conv_pw_12_bn (BatchNormali  (None, 1, 1, 1024)       4096
#  zation)
#
#  conv_pw_12_relu (ReLU)      (None, 1, 1, 1024)        0
#
#  conv_dw_13 (DepthwiseConv2D  (None, 1, 1, 1024)       9216
#  )
#
#  conv_dw_13_bn (BatchNormali  (None, 1, 1, 1024)       4096
#  zation)
#
#  conv_dw_13_relu (ReLU)      (None, 1, 1, 1024)        0
#
#  conv_pw_13 (Conv2D)         (None, 1, 1, 1024)        1048576
#
#  conv_pw_13_bn (BatchNormali  (None, 1, 1, 1024)       4096
#  zation)
#
#  conv_pw_13_relu (ReLU)      (None, 1, 1, 1024)        0
#
# =================================================================
# Total params: 3,228,864
# Trainable params: 0
# Non-trainable params: 3,228,864
# _________________________________________________________________

# %%
from tensorflow.keras.applications.mobilenet import MobileNet
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense,Flatten

# %%
model_mod = MobileNet_model.layers[-1].output
flatten = tf.keras.layers.Flatten()(model_mod)
denser = tf.keras.layers.Dense(128, activation = 'relu')(flatten)
dropout = tf.keras.layers.Dropout(0.5)(denser)
prediction = tf.keras.layers.Dense(2, activation = 'softmax')(dropout)

model2 = tf.keras.Model(inputs=MobileNet_model.input, outputs=prediction)

model2.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 50, 50, 3)]       0
#
#  conv1 (Conv2D)              (None, 25, 25, 32)        864
#
#  conv1_bn (BatchNormalizatio  (None, 25, 25, 32)       128
#  n)
#
#  conv1_relu (ReLU)           (None, 25, 25, 32)        0
#
#  conv_dw_1 (DepthwiseConv2D)  (None, 25, 25, 32)       288
#
#  conv_dw_1_bn (BatchNormaliz  (None, 25, 25, 32)       128
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, 25, 25, 32)        0
#
#  conv_pw_1 (Conv2D)          (None, 25, 25, 64)        2048
#
#  conv_pw_1_bn (BatchNormaliz  (None, 25, 25, 64)       256
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, 25, 25, 64)        0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 26, 26, 64)        0
#
#  conv_dw_2 (DepthwiseConv2D)  (None, 12, 12, 64)       576
#
#  conv_dw_2_bn (BatchNormaliz  (None, 12, 12, 64)       256
#  ation)
#
#  conv_dw_2_relu (ReLU)       (None, 12, 12, 64)        0
#
#  conv_pw_2 (Conv2D)          (None, 12, 12, 128)       8192
#
#  conv_pw_2_bn (BatchNormaliz  (None, 12, 12, 128)      512
#  ation)
#
#  conv_pw_2_relu (ReLU)       (None, 12, 12, 128)       0
#
#  conv_dw_3 (DepthwiseConv2D)  (None, 12, 12, 128)      1152
#
#  conv_dw_3_bn (BatchNormaliz  (None, 12, 12, 128)      512
#  ation)
#
#  conv_dw_3_relu (ReLU)       (None, 12, 12, 128)       0
#
#  conv_pw_3 (Conv2D)          (None, 12, 12, 128)       16384
#
#  conv_pw_3_bn (BatchNormaliz  (None, 12, 12, 128)      512
#  ation)
#
#  conv_pw_3_relu (ReLU)       (None, 12, 12, 128)       0
#
#  conv_pad_4 (ZeroPadding2D)  (None, 13, 13, 128)       0
#
#  conv_dw_4 (DepthwiseConv2D)  (None, 6, 6, 128)        1152
#
#  conv_dw_4_bn (BatchNormaliz  (None, 6, 6, 128)        512
#  ation)
#
#  conv_dw_4_relu (ReLU)       (None, 6, 6, 128)         0
#
#  conv_pw_4 (Conv2D)          (None, 6, 6, 256)         32768
#
#  conv_pw_4_bn (BatchNormaliz  (None, 6, 6, 256)        1024
#  ation)
#
#  conv_pw_4_relu (ReLU)       (None, 6, 6, 256)         0
#
#  conv_dw_5 (DepthwiseConv2D)  (None, 6, 6, 256)        2304
#
#  conv_dw_5_bn (BatchNormaliz  (None, 6, 6, 256)        1024
#  ation)
#
#  conv_dw_5_relu (ReLU)       (None, 6, 6, 256)         0
#
#  conv_pw_5 (Conv2D)          (None, 6, 6, 256)         65536
#
#  conv_pw_5_bn (BatchNormaliz  (None, 6, 6, 256)        1024
#  ation)
#
#  conv_pw_5_relu (ReLU)       (None, 6, 6, 256)         0
#
#  conv_pad_6 (ZeroPadding2D)  (None, 7, 7, 256)         0
#
#  conv_dw_6 (DepthwiseConv2D)  (None, 3, 3, 256)        2304
#
#  conv_dw_6_bn (BatchNormaliz  (None, 3, 3, 256)        1024
#  ation)
#
#  conv_dw_6_relu (ReLU)       (None, 3, 3, 256)         0
#
#  conv_pw_6 (Conv2D)          (None, 3, 3, 512)         131072
#
#  conv_pw_6_bn (BatchNormaliz  (None, 3, 3, 512)        2048
#  ation)
#
#  conv_pw_6_relu (ReLU)       (None, 3, 3, 512)         0
#
#  conv_dw_7 (DepthwiseConv2D)  (None, 3, 3, 512)        4608
#
#  conv_dw_7_bn (BatchNormaliz  (None, 3, 3, 512)        2048
#  ation)
#
#  conv_dw_7_relu (ReLU)       (None, 3, 3, 512)         0
#
#  conv_pw_7 (Conv2D)          (None, 3, 3, 512)         262144
#
#  conv_pw_7_bn (BatchNormaliz  (None, 3, 3, 512)        2048
#  ation)
#
#  conv_pw_7_relu (ReLU)       (None, 3, 3, 512)         0
#
#  conv_dw_8 (DepthwiseConv2D)  (None, 3, 3, 512)        4608
#
#  conv_dw_8_bn (BatchNormaliz  (None, 3, 3, 512)        2048
#  ation)
#
#  conv_dw_8_relu (ReLU)       (None, 3, 3, 512)         0
#
#  conv_pw_8 (Conv2D)          (None, 3, 3, 512)         262144
#
#  conv_pw_8_bn (BatchNormaliz  (None, 3, 3, 512)        2048
#  ation)
#
#  conv_pw_8_relu (ReLU)       (None, 3, 3, 512)         0
#
#  conv_dw_9 (DepthwiseConv2D)  (None, 3, 3, 512)        4608
#
#  conv_dw_9_bn (BatchNormaliz  (None, 3, 3, 512)        2048
#  ation)
#
#  conv_dw_9_relu (ReLU)       (None, 3, 3, 512)         0
#
#  conv_pw_9 (Conv2D)          (None, 3, 3, 512)         262144
#
#  conv_pw_9_bn (BatchNormaliz  (None, 3, 3, 512)        2048
#  ation)
#
#  conv_pw_9_relu (ReLU)       (None, 3, 3, 512)         0
#
#  conv_dw_10 (DepthwiseConv2D  (None, 3, 3, 512)        4608
#  )
#
#  conv_dw_10_bn (BatchNormali  (None, 3, 3, 512)        2048
#  zation)
#
#  conv_dw_10_relu (ReLU)      (None, 3, 3, 512)         0
#
#  conv_pw_10 (Conv2D)         (None, 3, 3, 512)         262144
#
#  conv_pw_10_bn (BatchNormali  (None, 3, 3, 512)        2048
#  zation)
#
#  conv_pw_10_relu (ReLU)      (None, 3, 3, 512)         0
#
#  conv_dw_11 (DepthwiseConv2D  (None, 3, 3, 512)        4608
#  )
#
#  conv_dw_11_bn (BatchNormali  (None, 3, 3, 512)        2048
#  zation)
#
#  conv_dw_11_relu (ReLU)      (None, 3, 3, 512)         0
#
#  conv_pw_11 (Conv2D)         (None, 3, 3, 512)         262144
#
#  conv_pw_11_bn (BatchNormali  (None, 3, 3, 512)        2048
#  zation)
#
#  conv_pw_11_relu (ReLU)      (None, 3, 3, 512)         0
#
#  conv_pad_12 (ZeroPadding2D)  (None, 4, 4, 512)        0
#
#  conv_dw_12 (DepthwiseConv2D  (None, 1, 1, 512)        4608
#  )
#
#  conv_dw_12_bn (BatchNormali  (None, 1, 1, 512)        2048
#  zation)
#
#  conv_dw_12_relu (ReLU)      (None, 1, 1, 512)         0
#
#  conv_pw_12 (Conv2D)         (None, 1, 1, 1024)        524288
#
#  conv_pw_12_bn (BatchNormali  (None, 1, 1, 1024)       4096
#  zation)
#
#  conv_pw_12_relu (ReLU)      (None, 1, 1, 1024)        0
#
#  conv_dw_13 (DepthwiseConv2D  (None, 1, 1, 1024)       9216
#  )
#
#  conv_dw_13_bn (BatchNormali  (None, 1, 1, 1024)       4096
#  zation)
#
#  conv_dw_13_relu (ReLU)      (None, 1, 1, 1024)        0
#
#  conv_pw_13 (Conv2D)         (None, 1, 1, 1024)        1048576
#
#  conv_pw_13_bn (BatchNormali  (None, 1, 1, 1024)       4096
#  zation)
#
#  conv_pw_13_relu (ReLU)      (None, 1, 1, 1024)        0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 128)               131200
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 3,360,322
# Trainable params: 131,458
# Non-trainable params: 3,228,864
# _________________________________________________________________

# %%
model2.compile(Adam(learning_rate=0.001), loss="binary_crossentropy", 
              metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

filepath = "weights_MobileNet_trainable.h5"
checkpoint = ModelCheckpoint(filepath, monitor="val_accuracy", verbose=1, 
                             save_best_only=True, mode='max')
                              
                              
callbacks_list = [checkpoint]

history = model2.fit(train_gen, steps_per_epoch=train_steps, 
                    validation_data=val_gen,
                    validation_steps=val_steps,
                    epochs=64, verbose=1,
                   callbacks=callbacks_list)
# Out:
# Epoch 1/64
# 128/128 [==============================] - ETA: 0s - loss: 0.6883 - accuracy: 0.5415
# Epoch 00001: val_accuracy improved from -inf to 0.53223, saving model to weights_MobileNet_trainable.h5
# 128/128 [==============================] - 29s 215ms/step - loss: 0.6883 - accuracy: 0.5415 - val_loss: 0.6827 - val_accuracy: 0.5322
# Epoch 2/64
# 128/128 [==============================] - ETA: 0s - loss: 0.6792 - accuracy: 0.5732
# Epoch 00002: val_accuracy improved from 0.53223 to 0.59058, saving model to weights_MobileNet_trainable.h5
# 128/128 [==============================] - 27s 213ms/step - loss: 0.6792 - accuracy: 0.5732 - val_loss: 0.6739 - val_accuracy: 0.5906
# Epoch 3/64
# 128/128 [==============================] - ETA: 0s - loss: 0.
val_accuracy did not improve from 0.62122
# 128/128 [==============================] - 23s 182ms/step - loss: 0.6543 - accuracy: 0.6118 - val_loss: 0.6602 - val_accuracy: 0.6094
# Epoch 57/64
# 128/128 [==============================] - ETA: 0s - loss: 0.6555 - accuracy: 0.6172
# Epoch 00057: val_accuracy did not improve from 0.62122
# 128/128 [==============================] - 23s 181ms/step - loss: 0.6555 - accuracy: 0.6172 - val_loss: 0.6589 - val_accuracy: 0.6100
# Epoch 58/64
# 128/128 [==============================] - ETA: 0s - loss: 0.6525 - accuracy: 0.6238
# Epoch 00058: val_accuracy did not improve from 0.62122
# 128/128 [==============================] - 23s 182ms/step - loss: 0.6525 - accuracy: 0.6238 - val_loss: 0.6585 - val_accuracy: 0.6122
# Epoch 59/64
# 128/128 [==============================] - ETA: 0s - loss: 0.6598 - accuracy: 0.6145
# Epoch 00059: val_accuracy did not improve from 0.62122
# 128/128 [==============================] - 23s 181ms/step - loss: 0.6598 - accuracy: 0.6145 - val_loss: 0.6550 - val_accuracy: 0.6121
# Epoch 60/64
# 128/128 [==============================] - ETA: 0s - loss: 0.6532 - accuracy: 0.6133
# Epoch 00060: val_accuracy did not improve from 0.62122
# 128/128 [==============================] - 23s 182ms/step - loss: 0.6532 - accuracy: 0.6133 - val_loss: 0.6563 - val_accuracy: 0.6113
# Epoch 61/64
# 128/128 [==============================] - ETA: 0s - loss: 0.6579 - accuracy: 0.6191
# Epoch 00061: val_accuracy did not improve from 0.62122
# 128/128 [==============================] - 23s 182ms/step - loss: 0.6579 - accuracy: 0.6191 - val_loss: 0.6582 - val_accuracy: 0.6051
# Epoch 62/64
# 128/128 [==============================] - ETA: 0s - loss: 0.6569 - accuracy: 0.6130
# Epoch 00062: val_accuracy did not improve from 0.62122
# 128/128 [==============================] - 23s 182ms/step - loss: 0.6569 - accuracy: 0.6130 - val_loss: 0.6600 - val_accuracy: 0.6094
# Epoch 63/64
# 128/128 [==============================] - ETA: 0s - loss: 0.6549 - accuracy: 0.6133
# Epoch 00063: val_accuracy did not improve from 0.62122
# 128/128 [==============================] - 23s 183ms/step - loss: 0.6549 - accuracy: 0.6133 - val_loss: 0.6630 - val_accuracy: 0.6014
# Epoch 64/64
# 128/128 [==============================] - ETA: 0s - loss: 0.6532 - accuracy: 0.6204
# Epoch 00064: val_accuracy did not improve from 0.62122
# 128/128 [==============================] - 23s 182ms/step - loss: 0.6532 - accuracy: 0.6204 - val_loss: 0.6548 - val_accuracy: 0.6198

# %%
MobileNet_model.trainable = True

# %%
model2.compile(Adam(learning_rate=0.0001), loss="binary_crossentropy", 
              metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

filepath = "weights_MobileNet_trainable.h5"
checkpoint = ModelCheckpoint(filepath, monitor="val_accuracy", verbose=1, 
                             save_best_only=True, mode='max')
                              
                              
callbacks_list = [checkpoint]

history = model2.fit(train_gen, steps_per_epoch=train_steps, 
                    validation_data=val_gen,
                    validation_steps=val_steps,
                    epochs=64, verbose=1,
                   callbacks=callbacks_list)
# Out:
# Epoch 1/64
# 128/128 [==============================] - ETA: 0s - loss: 4.1819 - accuracy: 0.6577
# Epoch 00001: val_accuracy improved from -inf to 0.52917, saving model to weights_MobileNet_trainable.h5
# 128/128 [==============================] - 67s 511ms/step - loss: 4.1819 - accuracy: 0.6577 - val_loss: 0.9192 - val_accuracy: 0.5292
# Epoch 2/64
# 128/128 [==============================] - ETA: 0s - loss: 1.1840 - accuracy: 0.7241
# Epoch 00002: val_accuracy improved from 0.52917 to 0.65869, saving model to weights_MobileNet_trainable.h5
# 128/128 [==============================] - 76s 599ms/step - loss: 1.1840 - accuracy: 0.7241 - val_loss: 0.6914 - val_accuracy: 0.6587
# Epoch 3/64
# 128/128 [==============================] - ETA: 0s - loss: 0.7959 - accuracy: 0.7357
# Epoch 00003: val_accuracy improved from 0.65869 to 0.72839, saving model to weights_MobileNet_trainable.h5
# 128/128 [==============================] - 64s 503ms/step - loss: 0.7959 - accuracy: 0.7357 - val_loss: 0.5845 - val_accuracy: 0.7284
# Epoch 4/64
# 128/128 [==============================] - ETA: 0s - loss: 0.6074 - accuracy: 0.7484
# Epoch 00004: val_accuracy improved from 0.72839 to 0.76843, saving model to weights_MobileNet_trainable.h5
# 128/128 [==============================] - 63s 495ms/step - loss: 0.6074 - accuracy: 0.7484 - val_loss: 0.5222 - val_accuracy: 0.7684
# Epoch 5/64
# 128/128 [==============================] - ETA: 0s - loss: 0.5321 - accuracy: 0.7647
# Epoch 00005: val_accuracy improved from 0.76843 to 0.78320, saving model to weights_MobileNet_trainable.h5
# 128/128 [==============================] - 66s
metrics_names
# Out:
# ['loss', 'accuracy']

# %%
model2.save_weights("weights_MobileNet_trainable.h5")

# %%
# Here the best epoch will be used.

model2.load_weights('weights_MobileNet_trainable.h5')

# val_loss, val_acc = \
# model2.evaluate_generator(test_gen, 
#                         steps=len(df_val))
val_loss, val_accuracy = \
model2.evaluate(test_gen, 
                        steps=10168)
print('val_loss:', val_loss)
print('val_acc:', val_accuracy)
# Out:
# 10168/10168 [==============================] - 42s 4ms/step - loss: 0.3320 - accuracy: 0.8574
# val_loss: 0.3320275843143463
# val_acc: 0.8573957681655884

# %%
# display the loss and accuracy curves

import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.figure()

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_accuracy, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

# %%
# make a prediction
predictions = model2.predict(test_gen, steps=10168, verbose=1)
# Out:
# 10168/10168 [==============================] - 42s 4ms/step

# %%
predictions.shape
# Out:
# (10168, 2)

# %%
# This is how to check what index keras has internally assigned to each class. 
test_gen.class_indices
# Out:
# {'a_no_idc': 0, 'b_has_idc': 1}

# %%
# Put the predictions into a dataframe.
# The columns need to be oredered to match the output of the previous cell

df_preds = pd.DataFrame(predictions, columns=['no_idc', 'has_idc'])

df_preds.head()
# Out:
#      no_idc       has_idc
# 0  0.930208  6.979181e-02
# 1  0.974518  2.548220e-02
# 2  0.801860  1.981403e-01
# 3  1.000000  9.091048e-08
# 4  0.997301  2.699266e-03

# %%
# Get the true labels
y_true = test_gen.classes

# Get the predicted labels as probabilities
y_pred = df_preds['has_idc']

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_true, y_pred)
# Out:
# 0.9321899561791487

# %%
# Get the labels of the test images.

test_labels = test_gen.classes

# %%
test_labels.shape
# Out:
# (10168,)

# %%
# argmax returns the index of the max value in a row
cm = confusion_matrix(test_labels, predictions.argmax(axis=1))

# %%
# Define the labels of the class indices. These need to match the 
# order shown above.
cm_plot_labels = ['no_idc', 'has_idc']

# %%
from sklearn.metrics import classification_report

# Generate a classification report

# For this to work we need y_pred as binary labels not as probabilities
y_pred_binary = predictions.argmax(axis=1)

report = classification_report(y_true, y_pred_binary, target_names=cm_plot_labels)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#       no_idc       0.84      0.88      0.86      5084
#      has_idc       0.87      0.83      0.85      5084
#
#     accuracy                           0.86     10168
#    macro avg       0.86      0.86      0.86     10168
# weighted avg       0.86      0.86      0.86     10168

# %%
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import seaborn as sn

# %%
cm = confusion_matrix(y_true, y_pred_binary)

# %%
fig = plt.figure()
fig.suptitle('confusion matrix')
sn.heatmap(cm, annot=True, fmt='d')
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 15.0, 'Predicted label')

# %%
balanced_acc=( (cm[0,0]/(cm[0,0]+cm[0,1])) + (cm[1,1]/(cm[1,0]+cm[1,1])) )/2
# F1-score = 2 x (Recall x Precision) / (Recall + Precision)
# Recall = TP/(TP+FN))
# Precision = TP/(TP+FP)
f1_score=( 2
          *
          #recall * precission
          ((cm[1,1]/(cm[1,1]+cm[1,0])) * (cm[1,1]/(cm[1,1]+cm[0,1])))
          /
          #recall + precission
          ((cm[1,1]/(cm[1,1]+cm[1,0])) + (cm[1,1]/(cm[1,1]+cm[0,1])))
)
Accuracy = (cm[1,1]+cm[0,0])/(cm[1,1]+cm[0,1]+cm[0,0]+cm[1,0])

print(Accuracy)
print(balanced_acc)
print(f1_score)
# Out:
# 0.8551337529504327
# 0.8551337529504327
# 0.8519151502965719
